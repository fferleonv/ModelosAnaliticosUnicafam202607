# %% [markdown]
# <a href="https://colab.research.google.com/github/fferleonv/ModelosAnaliticosUnicafam202607/blob/main/Actividad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INTRODUCCION A PYTHON
#
# # MODELOS ANALITICOS
#
# # UNICAFAN
#
# # DOCENTE: NICOLAS MOJICA
#
# # ESTUDIANTE: JENIFFER LEON
#
# ACTIVIDAD: 01

# %% [markdown]
# #OPERADORES MATEMATICOS

# %%
a=10
b=3
suma=10+3
print=(suma)

# %% [markdown]
# #TEXTO
