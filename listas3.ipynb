# %% [markdown]
# <a href="https://colab.research.google.com/github/fferleonv/ModelosAnaliticosUnicafam202607/blob/main/listas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EJERCICIO 1: CREACION Y MODIFICACION DE LISTAS

# %%
# CREA UNA LISTA LLAMADA NUMEROS
numeros=[1,2,3,4,5]
print(numeros)
# Out:
# [1, 2, 3, 4, 5]

# %%
#añade el numero 6
numeros.append(6)
print(numeros)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#cambia el segundo elemento a 10
numeros[1]=10
print(numeros)
# Out:
# [1, 10, 3, 4, 5, 6]

# %%
# elimina el 4 elemento
numeros[3]
print(numeros)
# Out:
# [1, 10, 3, 4, 5, 6]
