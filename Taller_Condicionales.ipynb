# %% [markdown]
# <a href="https://colab.research.google.com/github/fferleonv/ModelosAnaliticosUnicafam202607/blob/main/Taller_Condicionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejercicios de las Condicionales**

# %% [markdown]
# Crea un programa que verifique si una persona es mayor de edad. Una persona es considerada mayor de edad si tiene 18 años o más.

# %%
# Validar si la persona es mayor de edad
edad=int(input("Introduce la edad: "))
if edad>=18:
  print("Eres mayor de edad")
else:
  print("Eres menor de edad")
# Out:
# Introduce la edad: 13
# Eres menor de edad

# %% [markdown]
# Escribe un programa que verifique si un número ingresado por el usuario es par o impar.

# %%
# numero impar o par
numero=int(input("Introduce un numero:  "))
if numero%2==0:
  print("El numero es par")
else:
  print("El numero es impar")
# Out:
# Introduce un numero:  3
# El numero es impar

# %% [markdown]
# Escribe un programa que clasifique la edad en diferentes categorías: Niño (0-12 años), Adolescente (13-17 años), Adulto (18-64 años) y Anciano (65 años o más).

# %%
# Clasificar por categorias
edad=int(input("Introduce la edad a clasificar:  "))
if edad<0:
  print("Edad no valida")
elif edad<=12:
    print("Categoria: Niño")
elif edad<=17:
  print("Categoria: Adolescente")
elif edad<65:
  print("Categoria Adulto")
else:
  print("Categoria Anciano")
# Out:
# Introduce la edad a clasificar:  66
# Categoria Anciano

# %% [markdown]
# Crea un programa que lea dos números y determine cuál es mayor, cuál es menor o si ambos son iguales.

# %%
# determinar con dos numeros mayor menor igual
numero1=float(input("Introduce el primer numero"))
numero2=float(input("Introduce el segundo numero"))

if numero1>numero2:
  print(f"El primer numero({numero1}) es mayor que el segundo({numero2})")
elif numero1<numero2:
  print(f"El primer numero({numero1})es menor que el segundo({numero2}) ")
else:
  print("Ambos numeros son iguales")
# Out:
# Introduce el primer numero2
# Introduce el segundo numero5
# El primer numero(2.0)es menor que el segundo(5.0)

# %% [markdown]
# Escribe un programa que pida al usuario una contraseña y verifique si es correcta. La contraseña correcta es "secreta123".

# %%
# Verificar contraseña
contraseña_correcta="secreta123"
intento=input("Introduce la contraseña ")
if intento==contraseña_correcta:
  print("Acceso aprobado. !en hora buena!")
else:
  print("Contraseña errada. Acceso denegado")
# Out:
# Introduce la contraseña secreta123
# Acceso aprobado. !en hora buena!

# %% [markdown]
# Crea un programa que determine si un número ingresado por el usuario está en el rango de 1 a 100 (inclusive) y si es divisible por 5.

# %%
#Determinar si un numero esta dentro del rango
numero=float(input("Escribe un numero: "))
if numero>=10 and numero<=50:
  print("El numero esta dentro del rango(10 a 50) ")
else:
  print("El numero esta fuera del rango ")
# Out:
# Escribe un numero: 60
# El numero esta fuera del rango
