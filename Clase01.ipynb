# %% [markdown]
# <a href="https://colab.research.google.com/github/fferleonv/ModelosAnaliticosUnicafam202607/blob/main/Clase01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCCION A PYTHON**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: JENIFFER LEON

# %% [markdown]
# ## COMENTARIOS DE CODIGO

# %%
#ESTE ES UN COMENTARIO DE UNA SOLA FILA
print("HOLA JENIFFER")
# Out:
# HOLA JENIFFER

# %%
"""
ESTE ES
UN COMENTARIO
DE VARIAS LINEAS
"""
# Out:
# '\nESTE ES\nUN COMENTARIO\nDE VARIAS LINEAS\n'

# %% [markdown]
# ## VARIABLES

# %%
var="HOLA MUNDO"
print(var)
# Out:
# HOLA MUNDO

# %%
#1.LAS VARIABLES DEBEN SER MINUSCULAS
#2.LAS VARIABLES NO DEBEN TENER ESPACIO
#3.LAS VARIABLES NO DEBEN CONTENER CARACTERES ESPECIALES

# %% [markdown]
# ## TIPOS DE DATOS

# %%
# ENTEROS
entero=5
entero_explicito=int(5)

#DECIMALES
decimal=5.0
decimal_explicito=float(5.0)

# %%
type(entero)
# Out:
# int

# %% [markdown]
# ## OPERADORES ARITMETICOS

# %%
a=10
b=5
c=a+b
print(a+b)
print(c)
# Out:
# 15
# 15

# %%
#DIVISION ENTERA
print(a//b)
# Out:
# 2

# %%
# MODULO
print(a%b)
# Out:
# 0

# %%
# LA EXPONENCIACIÓN
print(b**2)
# Out:
# 25

# %%
# ASIGNACION COMPUESTA
b+=2
print(b)
# Out:
# 7

# %% [markdown]
# ## TEXTOS

# %%
cadena="PYTHON ES GENIAL"
print(cadena[5])
# Out:
# N

# %%
# EXTRAER LA PALABRA PYTHON
print(cadena[0:6])
# Out:
# PYTHON

# %%
# EXTRAER LA PALABRA GENIAL
print(cadena[10:17])
# Out:
# GENIAL

# %%
# CONCATENACION DE VALORES
palabra1="HOLA"
palabra2="MUNDO"
print(palabra1+" ,"+palabra2)
# Out:
# HOLA ,MUNDO

# %%
# CAMBIOS DE FORMATO
print(cadena.upper())
# Out:
# PYTHON ES GENIAL

# %%
# CAMBIOS DE FORMATO
print(cadena.lower())
# Out:
# python es genial
